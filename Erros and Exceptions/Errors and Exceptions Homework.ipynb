# %% [markdown]
# #Errors and Exceptions Homework -

# %% [markdown]
# ###Problem 1
# Handle the exception thrown by the code below by using try and except blocks.

# %%
for i in ['a','b','c']:
    try:
        print(i ** 2) 
    except:
        print(str(i) + " Was not an integer!")
# Out:
# a Was not an integer!
# b Was not an integer!
# c Was not an integer!

# %% [markdown]
# ###Problem 2
# Handle the exception thrown by the code below by using **try** and **except** blocks. Then use a **finally** block to print 'All Done.'

# %%
x = 5
y = 0

try:
    z = x/y
except:
    if(y == 0):
        print("You can't divide a number by 0")
    else:
        print("Don't think I can do this calculation")
finally:
    print("all done")
# Out:
# You can't divide a number by 0
# all done

# %% [markdown]
# ###Problem 3
# Write a function that asks for an integer and prints the square of it. Use a while loop with a try,except, else block to account for incorrect inputs.

# %%
def ask():
    while True:
        try:
            answer = (int(input("Input an integer:"))**2)
        except:
            print("An error occured! Please try again!")
            continue
        else:
            break
    print ("Thank you, your number squared is: " + str(answer))

# %%
ask()
# Out:
# Input an integer:po
# An error occured! Please try again!
# Input an integer:3
# Thank you, your number squared is: 9

# %%
ask()
# Out:
# Input an integer: null
# An error occurred! Please try again!
# Input an integer: 2
# Thank you, you number squared is:  4

# %% [markdown]
# #Great Job!
